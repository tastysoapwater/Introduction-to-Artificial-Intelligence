# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("C:/Users/tisxo/AI_class/data/AAME.csv")

# %%
df
# Out:
#              Date  Open  High   Low  Close  Adj Close  Volume
# 0      1980-03-17  0.00  4.05  3.85   3.85   3.213167   15000
# 1      1980-03-18  0.00  4.00  3.80   3.80   3.171437   10200
# 2      1980-03-19  0.00  4.05  3.85   3.85   3.213167   33500
# 3      1980-03-20  0.00  4.00  3.80   3.80   3.171437    8700
# 4      1980-03-21  0.00  3.95  3.75   3.75   3.129709   12700
# ...           ...   ...   ...   ...    ...        ...     ...
# 10093  2020-03-26  2.29  2.29  2.08   2.28   2.280000    1600
# 10094  2020-03-27  2.25  2.25  2.21   2.25   2.250000     500
# 10095  2020-03-30  2.25  2.25  2.13   2.13   2.130000     400
# 10096  2020-03-31  2.11  2.11  2.11   2.11   2.110000     300
# 10097  2020-04-01  2.11  2.15  2.11   2.15   2.150000     600
#
# [10098 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df[df["Open"] == 0]
# Out:
#             Date  Open   High    Low  Close  Adj Close  Volume
# 0     1980-03-17   0.0   4.05   3.85   3.85   3.213167   15000
# 1     1980-03-18   0.0   4.00   3.80   3.80   3.171437   10200
# 2     1980-03-19   0.0   4.05   3.85   3.85   3.213167   33500
# 3     1980-03-20   0.0   4.00   3.80   3.80   3.171437    8700
# 4     1980-03-21   0.0   3.95   3.75   3.75   3.129709   12700
# ...          ...   ...    ...    ...    ...        ...     ...
# 1673  1986-10-28   0.0  10.80   9.60  10.00   8.833040   23100
# 1674  1986-10-29   0.0  10.40  10.00  10.40   9.186360   15800
# 1675  1986-10-30   0.0  10.80  10.60  10.60   9.363024   25200
# 1676  1986-10-31   0.0  11.00  10.60  10.60   9.363024    8600
# 1677  1986-11-03   0.0  11.00  10.60  10.80   9.539682    4200
#
# [1572 rows x 7 columns]

# %%
df = df.dropna()

# %%
openValues = df[['Open', 'High', 'Low', 'Close']].copy()
openValues = openValues[openValues['Open'] != 0]
# df에서 Open, High, Low, Close 열만 골라서 새로운 DataFrame openValues를 만드는 코드

# %%
# 시작가만 취한다.
seq_data = (openValues.to_numpy())
# 선형 그래프로 그린다.
plt.plot(seq_data, color='blue')
plt.title("")
plt.xlabel(" ")
plt.xlabel(" ")
plt.show()

# %%
df = df.drop(columns=['Adj Close', 'Volume'])

# %%
df.head()
# Out:
#          Date  Open  High   Low  Close
# 0  1980-03-17   0.0  4.05  3.85   3.85
# 1  1980-03-18   0.0  4.00  3.80   3.80
# 2  1980-03-19   0.0  4.05  3.85   3.85
# 3  1980-03-20   0.0  4.00  3.80   3.80
# 4  1980-03-21   0.0  3.95  3.75   3.75

# %%
scaler = MinMaxScaler(feature_range = (0, 1))
scaled = scaler.fit_transform(openValues)

# %%
TEST_SIZE = 2000
train_data = scaled[:-TEST_SIZE]
test_data = scaled[-TEST_SIZE:]

# %%
def make_sample(data, window):
    train = []
    target = []
    for i in range(len(data)-window):
        train.append(data[i:i+window])
        target.append(data[i+window][-1])
    return np.array(train), np.array(target)
    
window_size = 30         
X_train, y_train = make_sample(train_data, window_size)
X_test,  y_test  = make_sample(test_data,  window_size)

# %%
model = Sequential()
model.add(LSTM(64, 
                input_shape=(window_size, 4), 
                activation='tanh', 
                return_sequences=False)
          )
model.add(Dense(1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 64)                  │          17,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,729 (69.25 KB)
#  Trainable params: 17,729 (69.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, epochs = 100, batch_size = 16, validation_data = (X_test, y_test))
# Out:
# Epoch 1/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - loss: 8.4903e-04 - val_loss: 7.5062e-05
# Epoch 2/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.9980e-04 - val_loss: 7.3170e-05
# Epoch 3/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.7577e-04 - val_loss: 2.8838e-04
# Epoch 4/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.6695e-04 - val_loss: 6.4241e-05
# Epoch 5/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 1.9089e-04 - val_loss: 5.8898e-05
# Epoch 6/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 1.5524e-04 - val_loss: 6.5014e-05
# Epoch 7/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 1.6751e-04 - val_loss: 5.3641e-05
# Epoch 8/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 1.4317e-04 - val_loss: 6.2211e-05
# Epoch 9/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 1.6781e-04 - val_loss: 5.9396e-05
# Epoch 10/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 1.3684e-04 - val_loss: 5.1587e-05
# Epoch 11/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 1.5334e-04 - val_loss: 5.9123e-05
# Epoch 12/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1.2728e-04 - val_loss: 5.4659e-05
# Epoch 13/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 1.4379e-04 - val_loss: 8.3933e-05
# Epoch 14/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 1.3880e-04 - val_loss: 5.1623e-05
# Epoch 15/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - loss: 1.1787e-04 - val_loss: 5.1213e-05
# Epoch 16/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 1.1874e-04 - val_loss: 6.7710e-05
# Epoch 17/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1.3507e-04 - val_loss: 6.8501e-05
# Epoch 18/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1.6288e-04 - val_loss: 5.0381e-05
# Epoch 19/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1.3951e-04 - val_loss: 5.5229e-05
# Epoch 20/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 1.3360e-04 - val_loss: 1.0980e-04
# Epoch 21/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1.2715e-04 - val_loss: 5.0299e-05
# Epoch 22/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1.3696e-04 - val_loss: 5.0058e-05
# Epoch 23/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1.4965e-04 - val_loss: 5.0098e-05
# Epoch 24/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - loss: 1.2759e-04 - val_loss: 5.0249e-05
# Epoch 25/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - loss: 1.2300e-04 - val_loss: 4.9901e-05
# Epoch 26/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 1.3170e-04 - val_loss: 5.8060e-05
# Epoch 27/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 1.4633e-04 - val_loss: 1.3206e-04
# Epoch 28/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - loss: 1.4183e-04 - val_loss: 5.0612e-05
# Epoch 29/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 1.3585e-04 - val_loss: 5.5795e-05
# Epoch 30/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 1.2884e-04 - val_loss: 5.1356e-05
# Epoch 31/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 1.4134e-04 - val_loss: 6.0343e-05
# Epoch 32/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 1.3730e-04 - val_loss: 5.1990e-05
# Epoch 33/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 1.2385e-04 - val_loss: 5.7676e-05
# Epoch 34/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 16s 39ms/step - loss: 1.2645e-04 - val_loss: 5.2091e-05
# Epoch 35/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - loss: 1.3191e-04 - val_loss: 6.1964e-05
# Epoch 36/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - loss: 1.2691e-04 - val_loss: 5.5206e-05
# Epoch 37/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.3820e-04 - val_loss: 4.9749e-05
# Epoch 38/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.3794e-04 - val_loss: 6.2531e-05
# Epoch 39/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.2039e-04 - val_loss: 8.3309e-05
# Epoch 40/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.0778e-04 - val_loss: 5.0035e-05
# Epoch 41/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.1862e-04 - val_loss: 6.0465e-05
# Epoch 42/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.3832e-04 - val_loss: 9.9520e-05
# Epoch 43/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.3620e-04 - val_loss: 5.0969e-05
# Epoch 44/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.2062e-04 - val_loss: 5.0648e-05
# Epoch 45/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 1.3513e-04 - val_loss: 5.0757e-05
# Epoch 46/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.2991e-04 - val_loss: 6.0809e-05
# Epoch 47/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 1.2763e-04 - val_loss: 5.2655e-05
# Epoch 48/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.1343e-04 - val_loss: 6.2893e-05
# Epoch 49/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.2571e-04 - val_loss: 5.0313e-05
# Epoch 50/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.2117e-04 - val_loss: 5.0668e-05
# Epoch 51/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.4112e-04 - val_loss: 4.9567e-05
# Epoch 52/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.1902e-04 - val_loss: 6.0092e-05
# Epoch 53/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 1.2340e-04 - val_loss: 5.1000e-05
# Epoch 54/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - loss: 1.2320e-04 - val_loss: 1.1697e-04
# Epoch 55/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 1.1787e-04 - val_loss: 5.5072e-05
# Epoch 56/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 1.1252e-04 - val_loss: 1.0055e-04
# Epoch 57/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1.3873e-04 - val_loss: 4.9424e-05
# Epoch 58/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 1.3811e-04 - val_loss: 5.6174e-05
# Epoch 59/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1.2642e-04 - val_loss: 7.5765e-05
# Epoch 60/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1.2898e-04 - val_loss: 5.3141e-05
# Epoch 61/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - loss: 1.3811e-04 - val_loss: 5.8359e-05
# Epoch 62/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 1.1852e-04 - val_loss: 5.4926e-05
# Epoch 63/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 1.1922e-04 - val_loss: 5.0373e-05
# Epoch 64/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - loss: 1.1697e-04 - val_loss: 5.8463e-05
# Epoch 65/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 1.1511e-04 - val_loss: 5.3930e-05
# Epoch 66/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 1.2946e-04 - val_loss: 5.7486e-05
# Epoch 67/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 1.3732e-04 - val_loss: 6.2312e-05
# Epoch 68/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 1.1421e-04 - val_loss: 5.7110e-05
# Epoch 69/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - loss: 1.2094e-04 - val_loss: 5.0369e-05
# Epoch 70/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 1.0929e-04 - val_loss: 5.4323e-05
# Epoch 71/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - loss: 1.3087e-04 - val_loss: 5.3488e-05
# Epoch 72/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - loss: 1.1713e-04 - val_loss: 5.0659e-05
# Epoch 73/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 1.1239e-04 - val_loss: 5.0180e-05
# Epoch 74/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.1394e-04 - val_loss: 5.0706e-05
# Epoch 75/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.1979e-04 - val_loss: 5.0524e-05
# Epoch 76/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.1324e-04 - val_loss: 5.0393e-05
# Epoch 77/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.2748e-04 - val_loss: 7.0321e-05
# Epoch 78/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 1.2691e-04 - val_loss: 5.0769e-05
# Epoch 79/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 1.2639e-04 - val_loss: 5.1737e-05
# Epoch 80/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.2600e-04 - val_loss: 4.9947e-05
# Epoch 81/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 1.1893e-04 - val_loss: 5.1281e-05
# Epoch 82/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 1.1304e-04 - val_loss: 5.5145e-05
# Epoch 83/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 1.0272e-04 - val_loss: 7.5675e-05
# Epoch 84/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 1.1517e-04 - val_loss: 7.7128e-05
# Epoch 85/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 1.4031e-04 - val_loss: 5.2095e-05
# Epoch 86/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.1886e-04 - val_loss: 6.5509e-05
# Epoch 87/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.2980e-04 - val_loss: 5.0401e-05
# Epoch 88/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.0214e-04 - val_loss: 5.8965e-05
# Epoch 89/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.1572e-04 - val_loss: 6.1186e-05
# Epoch 90/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.1006e-04 - val_loss: 5.0017e-05
# Epoch 91/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.0371e-04 - val_loss: 6.0602e-05
# Epoch 92/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 1.0363e-04 - val_loss: 5.1286e-05
# Epoch 93/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.1331e-04 - val_loss: 5.2335e-05
# Epoch 94/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.1791e-04 - val_loss: 4.9702e-05
# Epoch 95/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.0241e-04 - val_loss: 5.9425e-05
# Epoch 96/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 1.2479e-04 - val_loss: 5.5440e-05
# Epoch 97/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.1844e-04 - val_loss: 5.5823e-05
# Epoch 98/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 1.1758e-04 - val_loss: 5.3019e-05
# Epoch 99/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - loss: 1.1535e-04 - val_loss: 5.0138e-05
# Epoch 100/100
# 406/406 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 1.1808e-04 - val_loss: 5.2430e-05

# %%
pred = model.predict(X_test)

import matplotlib.pyplot as plt
plt.figure(figsize=(12, 9))
plt.plot(y_test, label='Close price')
plt.plot(pred, label='predicted Close price')
plt.legend()
plt.show()
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
mse = mean_squared_error(y_test, pred)
print(f"MSE {mse:.6f}")
# Out:
# MSE 0.000052
